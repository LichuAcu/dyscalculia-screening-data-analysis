# %%
import pandas as pd
df = pd.read_csv('data-bug.csv')

# %%
idx = 0
for column in df:
    if "correct_answer" in column:
        if "numeric-line" in column:
            new_column = df[column] == df[f"{column[:-14]}user_answer"]
            df[f"{column[:-14]}user_score"] = new_column
    idx += 1
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3361: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df
# Out:
#              alias dots-comparison_RT dots-comparison_accuracy  \
# 0           Test 1             1283,3                        1
# 1            CataP             1800,1                        1
# 2         prueba 1               4099                        1
# 3             Ines             1074,2                        1
# 4    Prueba 5 (MZ)             9250,6                        1
# ..             ...                ...                      ...
# 108          RAMAG             1979,9                        1
# 109          PETMI             1779,1                      0,9
# 110          SAULO             2950,2                        1
# 111          ZUNMA             5434,2                        1
# 112          Trote             3592,6                      0,7
#
#     dots-comparison_IES  dots-comparison_1_correct_answer  \
# 0                1283,3                               4.0
# 1                1800,1                               9.0
# ...

# %%
s = "abcde"
s[:-1]
# Out:
# 'abcd'

# %%
import pandas as pd
df = pd.read_csv('data-polo.csv', sep=',', decimal='.')

# %%
for i in range(2,11):
    print(df[f"match-sample-rotate_{i}_user_answer"].head(3))
# Out:
# 0    FALSE
# 1     TRUE
# 2     TRUE
# Name: match-sample-rotate_2_user_answer, dtype: object
# 0     TRUE
# 1     TRUE
# 2    FALSE
# Name: match-sample-rotate_3_user_answer, dtype: object
# 0    FALSE
# 1     TRUE
# 2    FALSE
# Name: match-sample-rotate_4_user_answer, dtype: object
# 0     TRUE
# 1     TRUE
# 2    FALSE
# Name: match-sample-rotate_5_user_answer, dtype: object
# 0     TRUE
# 1    FALSE
# 2    FALSE
# Name: match-sample-rotate_6_user_answer, dtype: object
# 0     TRUE
# 1     TRUE
# 2    FALSE
# Name: match-sample-rotate_7_user_answer, dtype: object
# 0     TRUE
# 1     TRUE
# 2    FALSE
# Name: match-sample-rotate_8_user_answer, dtype: object
# 0     TRUE
# 1    FALSE
# 2    FALSE
# Name: match-sample-rotate_9_user_answer, dtype: object
# 0    FALSE
# 1     TRUE
# 2    FALSE
# Name: match-sample-rotate_10_user_answer, dtype: object

# %%
def prepare_column(df, column):
    if not (str(df[column])=="nan" or str(df[f"{column[:-14]}user_answer"])=="nan"):
        return (str(df[column]).upper() == str(df[f"{column[:-14]}user_answer"]).upper())
    return math.nan

for i in range(2,11):
    new_column = df.apply(prepare_column, axis=1, args=(f"match-sample-rotate_{i}_correct_answer",))
    df[f"match-sample-rotate_{i}_user_score"] = new_column.astype(float)

# %%
df.to_csv("complete_data-fixed.csv", index=False, decimal=".")

# %%
df["match-sample-rotate_3_user_score"].head(5)
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: match-sample-rotate_3_user_score, dtype: float64

# %%
df["match-sample-rotate_3_user_answer"].head(5)
# Out:
# 0     TRUE
# 1     TRUE
# 2    FALSE
# 3    FALSE
# 4    FALSE
# Name: match-sample-rotate_3_user_answer, dtype: object

# %%
df["match-sample-rotate_3_correct_answer"].head(5)
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: match-sample-rotate_3_correct_answer, dtype: bool
